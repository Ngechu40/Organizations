# %% [markdown]
# # Importing and Exploring the dataset

# %%
import numpy as np#This library is used for working with arrays.
import pandas as pd#This library is used for working with data sets,used for analyzing, cleaning,exploring, and manipulating data.
import seaborn as sns#it is used for making statistical graphics.
import matplotlib.pyplot as plt#This library is used to visualize data.
import os
os.chdir("C:/Users/user/Desktop")
df=pd.read_csv('organizations-10000.csv')
df
# Out:
#       Index  Organization Id                         Name  \
# 0         1  522816eF8fdBE6d                 Mckinney PLC
# 1         2  70C7FBD7e6Aa3Ea               Cunningham LLC
# 2         3  428B397eA2d7290                   Ruiz-Walls
# 3         4  9D234Ae8Cc51C1c  Parrish, Osborne and Clarke
# 4         5  6CDCcdE3D0b7b44       Diaz, Robles and Haley
# ...     ...              ...                          ...
# 9995   9996  2EE82AD1Cd045cd           Neal, Day and Wang
# 9996   9997  06f1568A2CaF04a    Barrett, Rojas and Adkins
# 9997   9998  B4B92A44e0331Bc               Franklin-Ayala
# 9998   9999  01D2539e270CEbd                  Wolfe-Mckee
# 9999  10000  0D3b7DcFA21d92d                     Beck LLC
#
#                             Website  \
# 0                  http://soto.com/
# 1         http://harding-duffy.com/
# 2            http://www.atkins.biz/
# 3              http://salazar.info/
# 4     https://www.brooks-scott.net/
# ...                             ...
# ...

# %%
df.info()#prints information about a dataframe including the index dtype and columns, non-null values and memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Index                10000 non-null  int64
#  1   Organization Id      10000 non-null  object
#  2   Name                 10000 non-null  object
#  3   Website              10000 non-null  object
#  4   Country              10000 non-null  object
#  5   Description          10000 non-null  object
#  6   Founded              10000 non-null  int64
#  7   Industry             10000 non-null  object
#  8   Number of employees  10000 non-null  int64
# dtypes: int64(3), object(6)
# memory usage: 703.2+ KB

# %%
df.describe().T#returns description of the data in the Dataframe
# Out:
#                        count       mean          std     min      25%     50%  \
# Index                10000.0  5000.5000  2886.895680     1.0  2500.75  5000.5
# Founded              10000.0  1995.7767    14.991608  1970.0  1983.00  1996.0
# Number of employees  10000.0  4961.3210  2911.862096     1.0  2446.75  4894.0
#
#                          75%      max
# Index                7500.25  10000.0
# Founded              2009.00   2022.0
# Number of employees  7530.00   9999.0

# %%
df.columns
# Out:
# Index(['Index', 'Organization Id', 'Name', 'Website', 'Country', 'Description',
#        'Founded', 'Industry', 'Number of employees'],
#       dtype='object')

# %%
df.shape
# Out:
# (10000, 9)

# %%
df.corr()#it is used to find the pairwise correlation of all columns
# Out:
#                         Index   Founded  Number of employees
# Index                1.000000  0.002466            -0.015114
# Founded              0.002466  1.000000            -0.026036
# Number of employees -0.015114 -0.026036             1.000000

# %%
df.nunique()#returns the number of unique values for each column
# Out:
# Index                  10000
# Organization Id        10000
# Name                    9210
# Website                 8298
# Country                  243
# Description             9952
# Founded                   53
# Industry                 147
# Number of employees     6341
# dtype: int64

# %% [markdown]
# ### Data cleaning

# %%
df.isnull().any()#indicates if any value is missing
# Out:
# Index                  False
# Organization Id        False
# Name                   False
# Website                False
# Country                False
# Description            False
# Founded                False
# Industry               False
# Number of employees    False
# dtype: bool

# %%
sns.heatmap(df.isnull(),yticklabels=False)#visualization of missing records in dataframe
# Out:
# <AxesSubplot:>

# %%
df.drop_duplicates()#return dataframe with duplicate rows removed
# Out:
#       Index  Organization Id                         Name  \
# 0         1  522816eF8fdBE6d                 Mckinney PLC
# 1         2  70C7FBD7e6Aa3Ea               Cunningham LLC
# 2         3  428B397eA2d7290                   Ruiz-Walls
# 3         4  9D234Ae8Cc51C1c  Parrish, Osborne and Clarke
# 4         5  6CDCcdE3D0b7b44       Diaz, Robles and Haley
# ...     ...              ...                          ...
# 9995   9996  2EE82AD1Cd045cd           Neal, Day and Wang
# 9996   9997  06f1568A2CaF04a    Barrett, Rojas and Adkins
# 9997   9998  B4B92A44e0331Bc               Franklin-Ayala
# 9998   9999  01D2539e270CEbd                  Wolfe-Mckee
# 9999  10000  0D3b7DcFA21d92d                     Beck LLC
#
#                             Website  \
# 0                  http://soto.com/
# 1         http://harding-duffy.com/
# 2            http://www.atkins.biz/
# 3              http://salazar.info/
# 4     https://www.brooks-scott.net/
# ...                             ...
# ...

# %% [markdown]
# ### Data visualization

# %%
sns.set_style('darkgrid')

# %%
sns.displot(df, x="Number of employees")

# %%
sns.set_style('darkgrid')

# %%
sns.displot(df, x="Founded")

# %%
results=df.groupby("Founded").sum()

# %%
Founded= range(1970,2023)
Number_of_employees=range(500,10000)
plt.bar(Founded,results['Number of employees'] )
plt.show()

# %%
data_count = df['Country'].value_counts().head(50)

# Create a DataFrame from the 'data_count' Series to access the 'Country' and 'Counts' columns.
df_counts = pd.DataFrame({'Country': data_count.index, 'Counts': data_count.values})

# Sort the DataFrame by the counts in descending order for a more meaningful line plot.
df_counts.sort_values(by='Counts', ascending=False, inplace=True)

# Plot the line plot
plt.figure(figsize=(10, 6))
plt.plot(df_counts['Country'], df_counts['Counts'], marker='o', linestyle='-', color='blue')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.xlabel('Country')
plt.ylabel('Counts')
plt.title('Count of Each Country')
plt.tight_layout()
plt.show()

# %%
data_count = df['Country'].value_counts().tail(50)

# Create a DataFrame from the 'data_count' Series to access the 'Country' and 'Counts' columns.
df_counts = pd.DataFrame({'Country': data_count.index, 'Counts': data_count.values})

# Sort the DataFrame by the counts in descending order for a more meaningful line plot.
df_counts.sort_values(by='Counts', ascending=False, inplace=True)

# Plot the line plot
plt.figure(figsize=(10, 6))
plt.plot(df_counts['Country'], df_counts['Counts'], marker='o', linestyle='-', color='blue')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.xlabel('Country')
plt.ylabel('Counts')
plt.title('Count of Each Country')
plt.tight_layout()
plt.show()

# %%
data_count = df['Industry'].value_counts().head(50)

# Create a DataFrame from the 'data_count' Series to access the 'Industry' and 'Counts' columns.
df_counts = pd.DataFrame({'Industry': data_count.index, 'Counts': data_count.values})

# Sort the DataFrame by the counts in descending order for a more meaningful line plot.
df_counts.sort_values(by='Counts', ascending=False, inplace=True)

# Plot the line plot
plt.figure(figsize=(10, 6))
plt.plot(df_counts['Industry'], df_counts['Counts'], marker='o', linestyle='-', color='blue')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.xlabel('Industry')
plt.ylabel('Counts')
plt.title('Count of Each Industry')
plt.tight_layout()
plt.show()

# %%
data_count = df['Industry'].value_counts().tail(50)

# Create a DataFrame from the 'data_count' Series to access the 'Industry' and 'Counts' columns.
df_counts = pd.DataFrame({'Industry': data_count.index, 'Counts': data_count.values})

# Sort the DataFrame by the counts in descending order for a more meaningful line plot.
df_counts.sort_values(by='Counts', ascending=False, inplace=True)

# Plot the line plot
plt.figure(figsize=(10, 6))
plt.plot(df_counts['Industry'], df_counts['Counts'], marker='o', linestyle='-', color='blue')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.xlabel('Industry')
plt.ylabel('Counts')
plt.title('Count of Each Industry')
plt.tight_layout()
plt.show()
